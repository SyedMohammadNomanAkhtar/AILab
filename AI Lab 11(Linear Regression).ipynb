# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics

dataset = pd.read_excel(r"Salary.xlsx")
x = dataset['YearsExperience'].values.reshape(-1, 1)
y = dataset['Salary'].values.reshape(-1, 1)


dataset.plot(x='YearsExperience', y='Salary', style='o')
plt.title('YearsExperience vs Salary')
plt.xlabel('YearsExperience')
plt.ylabel('Salary')
plt.show()

xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size=0.2, random_state=0)

linearRegressor = LinearRegression()
linearRegressor.fit(xTrain, yTrain)

yPrediction = linearRegressor.predict(xTest)

df = pd.DataFrame({'Actual': yTest.flatten(), 'Predicted': yPrediction.flatten()})
print(df)

plt.scatter(xTrain, yTrain, color='red')
plt.plot(xTrain, linearRegressor.predict(xTrain), color='blue')
plt.title('Salary vs Experience (Training set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

plt.scatter(xTest, yTest, color='red')
plt.plot(xTest, yPrediction, color='blue')
plt.title('Salary vs Experience (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()

print('Mean Absolute Error:', metrics.mean_absolute_error(yTest, yPrediction))
print('Mean Squared Error:', metrics.mean_squared_error(yTest, yPrediction))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(yTest, yPrediction)))
# Out:
#    Actual     Predicted
# 0   63218  59720.421895
# 1   46205  37846.128480
# 2   64445  53831.189053
# 3   81363  76546.801445
# Mean Absolute Error: 6821.614781883849
# Mean Squared Error: 54488134.2595118
# Root Mean Squared Error: 7381.607837017068

# %% [markdown]
# ### Task 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics


dataset = pd.read_excel(r"weather.xlsx")

dataset.dropna(subset=['Basel Temperature [2 m elevation corrected]', 'Basel Growing Degree Days [2 m elevation corrected]'], inplace=True)

x = dataset['Basel Temperature [2 m elevation corrected]'].values.reshape(-1, 1)
y = dataset['Basel Growing Degree Days [2 m elevation corrected]'].values.reshape(-1, 1)


dataset.plot(x='Basel Temperature [2 m elevation corrected]', y='Basel Growing Degree Days [2 m elevation corrected]', style='o')
plt.title('Temperature vs Degree Days')
plt.xlabel('Basel Temperature')
plt.ylabel('Basel Growing Degree Days')
plt.show()

xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size=0.2, random_state=0)

linearRegressor = LinearRegression()
linearRegressor.fit(xTrain, yTrain)

yPrediction = linearRegressor.predict(xTest)

df = pd.DataFrame({'Actual': yTest.flatten(), 'Predicted': yPrediction.flatten()})
print(df)

plt.scatter(xTrain, yTrain, color='red')
plt.plot(xTrain, linearRegressor.predict(xTrain), color='blue')
plt.title('Temperature vs Degree Days (Training set)')
plt.xlabel('Basel Temperature')
plt.ylabel('Basel Growing Degree Days')
plt.show()

plt.scatter(xTest, yTest, color='red')
plt.plot(xTest, yPrediction, color='blue')
plt.title('Temperature vs Degree Days (Test set)')
plt.xlabel('Basel Temperature')
plt.ylabel('Basel Growing Degree Days')
plt.show()

print('Mean Absolute Error:', metrics.mean_absolute_error(yTest, yPrediction))
print('Mean Squared Error:', metrics.mean_squared_error(yTest, yPrediction))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(yTest, yPrediction)))
# Out:
#         Actual  Predicted
# 0     0.208760   0.255430
# 1     0.000000  -0.090725
# 2     0.000000  -0.099588
# 3     0.336677   0.333169
# 4     0.000000   0.092101
# ...        ...        ...
# 2420  0.177094   0.236185
# 2421  0.000000  -0.109970
# 2422  0.340844   0.335701
# 2423  0.000000  -0.227212
# 2424  0.000000   0.082732
#
# [2425 rows x 2 columns]
# Mean Absolute Error: 0.07700048268149202
# Mean Squared Error: 0.00851770212444968
# Root Mean Squared Error: 0.09229139788977996

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics


dataset = pd.read_excel(r"weather.xlsx")

dataset.dropna(subset=['Basel Temperature [2 m elevation corrected]', 'Basel Growing Degree Days [2 m elevation corrected]'], inplace=True)

x = dataset['Basel Temperature [2 m elevation corrected]'].values.reshape(-1, 1)
y = dataset['Basel Wind Speed [10 m]'].values.reshape(-1, 1)


dataset.plot(x='Basel Temperature [2 m elevation corrected]', y='Basel Wind Speed [10 m]', style='o')
plt.title('Temperature vs Wind Speed')
plt.xlabel('Basel Temperature')
plt.ylabel('Basel Wind Speed')
plt.show()

xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size=0.2, random_state=0)

linearRegressor = LinearRegression()
linearRegressor.fit(xTrain, yTrain)

yPrediction = linearRegressor.predict(xTest)

df = pd.DataFrame({'Actual': yTest.flatten(), 'Predicted': yPrediction.flatten()})
print(df)

plt.scatter(xTrain, yTrain, color='red')
plt.plot(xTrain, linearRegressor.predict(xTrain), color='blue')
plt.title('Temperature vs Wind Speed (Training set)')
plt.xlabel('Basel Temperature')
plt.ylabel('Basel Wind Speed')
plt.show()

plt.scatter(xTest, yTest, color='red')
plt.plot(xTest, yPrediction, color='blue')
plt.title('Temperature vs Wind Speed (Test set)')
plt.xlabel('Basel Temperature')
plt.ylabel('Basel Wind Speed')
plt.show()

print('Mean Absolute Error:', metrics.mean_absolute_error(yTest, yPrediction))
print('Mean Squared Error:', metrics.mean_squared_error(yTest, yPrediction))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(yTest, yPrediction)))
# Out:
#          Actual  Predicted
# 0      3.600000   7.862899
# 1      5.154415   7.716266
# 2      8.311245   7.712512
# 3      6.638072   7.895830
# 4      5.001280   7.793712
# ...         ...        ...
# 2420   4.198285   7.854747
# 2421   3.600000   7.708114
# 2422   1.835647   7.896903
# 2423   6.297428   7.658449
# 2424  14.764390   7.789743
#
# [2425 rows x 2 columns]
# Mean Absolute Error: 3.405752482388821
# Mean Squared Error: 21.06455558080387
# Root Mean Squared Error: 4.589613881450581

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics


dataset = pd.read_excel(r"weather.xlsx")

dataset.dropna(subset=['Basel Temperature [2 m elevation corrected]', 'Basel Wind Direction [10 m]'], inplace=True)

x = dataset['Basel Temperature [2 m elevation corrected]'].values.reshape(-1, 1)
y = dataset['Basel Wind Direction [10 m]'].values.reshape(-1, 1)


dataset.plot(x='Basel Temperature [2 m elevation corrected]', y='Basel Wind Speed [10 m]', style='o')
plt.title('Temperature vs Wind Direction')
plt.xlabel('Basel Temperature')
plt.ylabel('Basel Wind Direction')
plt.show()

xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size=0.2, random_state=0)

linearRegressor = LinearRegression()
linearRegressor.fit(xTrain, yTrain)

yPrediction = linearRegressor.predict(xTest)

df = pd.DataFrame({'Actual': yTest.flatten(), 'Predicted': yPrediction.flatten()})
print(df)

plt.scatter(xTrain, yTrain, color='red')
plt.plot(xTrain, linearRegressor.predict(xTrain), color='blue')
plt.title('Temperature vs Wind Direction (Training set)')
plt.xlabel('Basel Temperature')
plt.ylabel('Basel Wind Direction')
plt.show()

plt.scatter(xTest, yTest, color='red')
plt.plot(xTest, yPrediction, color='blue')
plt.title('Temperature vs Wind Speed (Test set)')
plt.xlabel('Basel Temperature')
plt.ylabel('Basel Wind Direction')
plt.show()

print('Mean Absolute Error:', metrics.mean_absolute_error(yTest, yPrediction))
print('Mean Squared Error:', metrics.mean_squared_error(yTest, yPrediction))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(yTest, yPrediction)))
# Out:
#           Actual   Predicted
# 0     323.130130  165.205487
# 1     114.775140  156.467193
# 2     342.349880  156.243462
# 3     229.398710  167.167929
# 4     300.256440  161.082444
# ...          ...         ...
# 2420  149.036240  164.719671
# 2421   53.130096  155.981377
# 2422  101.309930  167.231851
# 2423  120.963745  153.021735
# 2424  225.000000  160.845929
#
# [2425 rows x 2 columns]
# Mean Absolute Error: 78.72387805684136
# Mean Squared Error: 8961.961253638137
# Root Mean Squared Error: 94.66763572434952

# %% [markdown]
# ### Task 3

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import metrics


dataset = pd.read_excel(r"Job_Scheduling.xlsx")

dataset.dropna(subset=['Burst time', 'Arrival Time'], inplace=True)

x = dataset['Burst time'].values.reshape(-1, 1)
y = dataset['Arrival Time'].values.reshape(-1, 1)


dataset.plot(x='Burst time', y='Arrival Time', style='o')
plt.title('Burst time vs Arrival Time')
plt.xlabel('Burst time')
plt.ylabel('Arrival Time')
plt.show()

xTrain, xTest, yTrain, yTest = train_test_split(x, y, test_size=0.2, random_state=0)

linearRegressor = LinearRegression()
linearRegressor.fit(xTrain, yTrain)

yPrediction = linearRegressor.predict(xTest)

df = pd.DataFrame({'Actual': yTest.flatten(), 'Predicted': yPrediction.flatten()})
print(df)

plt.scatter(xTrain, yTrain, color='red')
plt.plot(xTrain, linearRegressor.predict(xTrain), color='blue')
plt.title('Burst time vs Arrival Time (Training set)')
plt.xlabel('Burst time')
plt.ylabel('Arrival Time')
plt.show()

plt.scatter(xTest, yTest, color='red')
plt.plot(xTest, yPrediction, color='blue')
plt.title('Burst time vs Arrival Time (Test set)')
plt.xlabel('Burst time')
plt.ylabel('Arrival Time')
plt.show()

print('Mean Absolute Error:', metrics.mean_absolute_error(yTest, yPrediction))
print('Mean Squared Error:', metrics.mean_squared_error(yTest, yPrediction))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(yTest, yPrediction)))
# Out:
#    Actual  Predicted
# 0  0.7800   0.332657
# 1  0.9875   0.403301
# 2  0.2150   0.302234
# 3  0.5675   0.347611
# Mean Absolute Error: 0.33466615663337324
# Mean Squared Error: 0.1493411861811179
# Root Mean Squared Error: 0.38644687368526853

# %% [markdown]
# ### Improve Model Results:
# #### Feature engineering: Create additional features like polynomial features or interaction terms to capture more complex relationships.
# #### Regularization: Apply regularization techniques like Ridge Regression or Lasso Regression to prevent overfitting and improve generalization.
# #### Cross-validation and hyperparameter tuning: Perform cross-validation and tune the hyperparameters of the model using techniques like Grid Search or Random Search.
# #### Ensemble methods: Explore ensemble methods like Random Forest Regression or Gradient Boosting Regression to potentially improve performance.
